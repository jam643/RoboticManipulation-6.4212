# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * 4.1 a) 2 points. There are 3 DoF in 2D. First point constrains 2 DoF, 2nd constrains 3rd
# * 4.1 b) 3 points. There are 6 DoF in 3D. First point constrains 3 DoF, 2nd constrains 2 (3 DoF - 1 constraint),  3rd constrains remaining 1.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * a) the decision variables are $x, y$ for ${}^{W}p^{O} = [x, y]^T$
# * b) the objective is $J = \sum||{}^{W}p^{O} + ^{W}R^{OO}p^{mi} - {}^{W}p^{si}||^2$.
#   * for $p^O = (0, 0)$ we have $J = 3 * (9 + 100) = \bold{327}$
#   * for $p^O = (3, 10)$ we have $J = \bold{0}$
#   * for $p^O = (6, 12)$ we have $J = 3 * (9 + 4) = \bold{36}$
# * c) the objective function is quadratic in $x, y$. This is significant because it falls into the QP category which guarantees local min is global min and allows using faster solvers
# * d)
